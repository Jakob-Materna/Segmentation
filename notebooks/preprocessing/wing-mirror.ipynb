# %%
import matplotlib.pyplot as plt
import cv2

from PIL import Image


file = "/mnt/c/Projects/Master/Data/Segmented/Hive02_Sheet_02/Hive02_Sheet_02_Label_64_Only.jpg"


wing = Image.open(file)
wing = wing.transpose(method=Image.FLIP_LEFT_RIGHT)


# Show image
plt.figure(figsize=(5, 5))
plt.imshow(wing)
plt.axis('off')
plt.show()

wing.save(file)
